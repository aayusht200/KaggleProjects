# %%
import pandas as pd  # Importing the pandas library for data manipulation and analysis
import matplotlib.pyplot as plt  # Importing the matplotlib library for data visualization
import datetime as dt  # Importing the datetime module for working with dates and times

# %%
companies = pd.read_csv("Unicorn_Companies.csv")  
# Reading the CSV file containing unicorn companies data into a pandas DataFrame

# %%
companies.head(10)  # Displaying the first 10 rows of the DataFrame to inspect the data
# Out:
#         Company Valuation Date Joined                             Industry  \
# 0     Bytedance     $180B      4/7/17              Artificial intelligence
# 1        SpaceX     $100B     12/1/12                                Other
# 2         SHEIN     $100B      7/3/18      E-commerce & direct-to-consumer
# 3        Stripe      $95B     1/23/14                              Fintech
# 4        Klarna      $46B    12/12/11                              Fintech
# 5         Canva      $40B      1/8/18         Internet software & services
# 6  Checkout.com      $40B      5/2/19                              Fintech
# 7     Instacart      $39B    12/30/14  Supply chain, logistics, & delivery
# 8     JUUL Labs      $38B    12/20/17                    Consumer & retail
# 9    Databricks      $38B      2/5/19          Data management & analytics
#
#             City  Country/Region      Continent  Year Founded Funding  \
# 0        Beijing           China           Asia          2012     $8B
# ...

# %%
companies.size  # Calculating the total number of elements (rows * columns) in the DataFrame
# Out:
# 10740

# %%
companies.shape  # Retrieving the dimensions of the DataFrame (number of rows, number of columns)
# Out:
# (1074, 10)

# %%
companies.info()  
# Providing concise summary information about the DataFrame including column data types and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
companies.describe()  # Generating descriptive statistics for numerical columns in the DataFrame
# Out:
#        Year Founded
# count   1074.000000
# mean    2012.895717
# std        5.698573
# min     1919.000000
# 25%     2011.000000
# 50%     2014.000000
# 75%     2016.000000
# max     2021.000000

# %%
companies['Date Joined'] = pd.to_datetime(companies['Date Joined'])  # Converting the 'Date Joined' column to datetime format
companies  # Displaying the updated DataFrame with the 'Date Joined' column converted to datetime
# Out:
# /var/folders/l8/6zdmd8v93qq3nyxx8vdq4hrc0000gn/T/ipykernel_45192/1238223733.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   companies['Date Joined'] = pd.to_datetime(companies['Date Joined'])  # Converting the 'Date Joined' column to datetime format
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# ...

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 84.0+ KB

# %%
companies['Join_year'] = companies['Date Joined'].dt.year  
# Extracting the year from the 'Date Joined' column and creating a new column 'Join_year'

# %%
companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City Country/Region      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors  Join_year
# 0  Sequoia Capital China, SIG Asia Investments, S...       2017
# ...

# %%
companies_sampled = companies.sample(n=50, random_state=40) 
# Sampling 50 random rows from the DataFrame with a random state of 40

# %%
companies_sampled.head()
# Out:
#                Company Valuation Date Joined  \
# 599      Xinchao Media       $2B  2018-04-09
# 49          OutSystems      $10B  2018-06-05
# 383   Pantheon Systems       $2B  2021-07-13
# 690     Clarify Health       $1B  2022-04-05
# 1025            Skydio       $1B  2021-02-25
#
#                                  Industry           City Country/Region  \
# 599          Internet software & services        Chengdu          China
# 49           Internet software & services         Boston  United States
# 383          Internet software & services  San Francisco  United States
# 690                                Health  San Francisco  United States
# 1025  Supply chain, logistics, & delivery   Redwood City  United States
#
#           Continent  Year Founded Funding  \
# 599            Asia          2007   $768M
# 49    North America          2001   $572M
# 383   North America          2010   $200M
# 690   North America          2015   $328M
# ...

# %%
companies_sampled['year_to_unicorn'] = companies_sampled['Join_year'] - companies_sampled['Year Founded']  
# Calculating the number of years it took for each sampled company to become a unicorn
grouped = companies_sampled[['Industry', 'year_to_unicorn']].groupby('Industry').max().sort_values('year_to_unicorn')  
# Grouping the data by industry and finding the maximum years to unicorn
grouped  
# Displaying the grouped data showing the maximum years to unicorn for each industry
# Out:
#                                      year_to_unicorn
# Industry
# Artificial Intelligence                            2
# Mobile & telecommunications                        4
# Data management & analytics                        6
# Edtech                                             6
# Cybersecurity                                      7
# Supply chain, logistics, & delivery                7
# Other                                              9
# Artificial intelligence                           10
# Auto & transportation                             11
# Fintech                                           12
# E-commerce & direct-to-consumer                   18
# Internet software & services                      18
# Consumer & retail                                 22
# Health                                            25

# %%
plt.bar(data=grouped, x=grouped.index, height=grouped['year_to_unicorn'])  
# Creating a bar plot with industry names on the x-axis and years to unicorn on the y-axis
plt.title('Bar plot of maximum years taken by company to become unicorn per industry (from sample)')  
# Setting the title of the plot
plt.xlabel('Industry')  # Labeling the x-axis
plt.ylabel('Years to Become a Unicorn')  # Labeling the y-axis
plt.xticks(rotation=45, horizontalalignment='right')  # Rotating x-axis labels for better readability
plt.show()  # Displaying the plot

# %%
companies_sampled.head()
# Out:
#                Company Valuation Date Joined  \
# 599      Xinchao Media       $2B  2018-04-09
# 49          OutSystems      $10B  2018-06-05
# 383   Pantheon Systems       $2B  2021-07-13
# 690     Clarify Health       $1B  2022-04-05
# 1025            Skydio       $1B  2021-02-25
#
#                                  Industry           City Country/Region  \
# 599          Internet software & services        Chengdu          China
# 49           Internet software & services         Boston  United States
# 383          Internet software & services  San Francisco  United States
# 690                                Health  San Francisco  United States
# 1025  Supply chain, logistics, & delivery   Redwood City  United States
#
#           Continent  Year Founded Funding  \
# 599            Asia          2007   $768M
# 49    North America          2001   $572M
# 383   North America          2010   $200M
# 690   North America          2015   $328M
# ...

# %%
companies_sampled['Valuation_int'] = companies_sampled['Valuation'].str[1:-1].astype(int)  
# Converting the 'Valuation' column to integer after removing the dollar sign and 'B' suffix
companies_sampled.info()  
# Displaying information about the DataFrame to confirm the changes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 599 to 215
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           50 non-null     object
#  1   Valuation         50 non-null     object
#  2   Date Joined       50 non-null     datetime64[ns]
#  3   Industry          50 non-null     object
#  4   City              49 non-null     object
#  5   Country/Region    50 non-null     object
#  6   Continent         50 non-null     object
#  7   Year Founded      50 non-null     int64
#  8   Funding           50 non-null     object
#  9   Select Investors  50 non-null     object
#  10  Join_year         50 non-null     int32
#  11  year_to_unicorn   50 non-null     int64
#  12  Valuation_int     50 non-null     int64
# dtypes: datetime64[ns](1), int32(1), int64(3), object(8)
# memory usage: 5.3+ KB

# %%
grouped = companies_sampled[['Industry', 'Valuation_int']].groupby('Industry').sum('Valuation_int').sort_values('Valuation_int')  
# Grouping the data by industry and summing the valuations
grouped  # Displaying the grouped data showing the total valuation for each industry
# Out:
#                                      Valuation_int
# Industry
# Artificial Intelligence                          1
# Edtech                                           1
# Other                                            1
# Cybersecurity                                    3
# Supply chain, logistics, & delivery              4
# Auto & transportation                            5
# Mobile & telecommunications                      5
# Consumer & retail                               13
# E-commerce & direct-to-consumer                 16
# Health                                          29
# Internet software & services                    32
# Data management & analytics                     49
# Fintech                                        131
# Artificial intelligence                        186

# %%
grouped
# Out:
#                                      Valuation_int
# Industry
# Artificial Intelligence                          1
# Edtech                                           1
# Other                                            1
# Cybersecurity                                    3
# Supply chain, logistics, & delivery              4
# Auto & transportation                            5
# Mobile & telecommunications                      5
# Consumer & retail                               13
# E-commerce & direct-to-consumer                 16
# Health                                          29
# Internet software & services                    32
# Data management & analytics                     49
# Fintech                                        131
# Artificial intelligence                        186

# %%
plt.bar(grouped.index, grouped['Valuation_int'])  
# Creating a bar plot with industry names on the x-axis and total valuation on the y-axis
plt.title('Bar Graph to see which industry has the max evaluations from 50 Random Unicorn Companies') 
# Setting the title of the plot
plt.xlabel('Industry')  # Labeling the x-axis
plt.ylabel('Evaluation')  # Labeling the y-axis
plt.xticks(rotation=45, horizontalalignment='right')  # Rotating x-axis labels for better readability
plt.show()  # Displaying the plot
